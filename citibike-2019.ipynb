# %%
import pandas as pd

# %% [markdown]
# # MERGE CSV

# %%
df1 = pd.read_csv("Resources/2019/JC-201906-citibike-tripdata.csv")
df2 = pd.read_csv("Resources/2019/JC-201907-citibike-tripdata.csv")
df3 = pd.read_csv("Resources/2019/JC-201908-citibike-tripdata.csv")

# %%
data = [df1, df2, df3]
df = pd.concat(data).drop_duplicates()

# %%
df.to_csv("Resources/2019/2019-citibike-combined.csv", index=False)

# %%
# Read in new csv
df = pd.read_csv("Resources/2018/2018-citibike-combined.csv")
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1           259  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2           686  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3           164  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4           769  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
# Convert trip duration column from seconds to minutes
df["tripduration"] = [trip/60 for trip in df["tripduration"]]

# Rename trip duration column
df.rename(columns={"tripduration":"tripduration (min)"})

df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0      5.483333  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1      4.316667  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2     11.433333  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3      2.733333  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4     12.816667  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
# Drop rows without a min of 2min and where the start and end stations are the same
df = df.loc[((df["tripduration"]>2) & (df["start station id"] != df["end station id"])),:]
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0      5.483333  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1      4.316667  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2     11.433333  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3      2.733333  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4     12.816667  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
# Filter out trips longer than 24 hours 
df = df.loc[df["tripduration"] < 1440, :]
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0      5.483333  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1      4.316667  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2     11.433333  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3      2.733333  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4     12.816667  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
# Rename values in gender column with strings
gender = {0:"Unknown", 1:"Male", 2:"Female"}
df.gender = [gender[item] for item in df.gender]
df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0           5.483333  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1           4.316667  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2          11.433333  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3           2.733333  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4          12.816667  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
# ...              ...                       ...                       ...
# 127632      7.700000  2018-08-25 16:17:05.8840  2018-08-25 16:24:48.5890
# 127633     10.600000  2018-08-28 12:31:22.4380  2018-08-28 12:41:59.2110
# 127634     15.900000  2018-08-30 08:08:18.9250  2018-08-30 08:24:13.7900
# 127635     15.333333  2018-08-31 08:08:54.2450  2018-08-31 08:24:14.8890
# 127636     16.950000  2018-08-31 12:57:23.8390  2018-08-31 13:14:20.9290
#
#         start station id start station name  start station latitude  \
# ...

# %%
df.to_csv("Resources/2019/2019-citibike-summer.csv", index=False)
